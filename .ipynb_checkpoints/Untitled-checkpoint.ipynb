# %%
# !pip install pytrends

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrends = TrendReq(hl='pt-BR', tz=360)

# %%
pytrends

# %%
pytrends.build_payload(kw_list=['todos os cantos'])

# %%
time_df = pytrends.interest_over_time()
time_df.head()
# Out:
#             todos os cantos  isPartial
# date
# 2017-04-09                2      False
# 2017-04-16                1      False
# 2017-04-23                3      False
# 2017-04-30                2      False
# 2017-05-07                1      False

# %%
df = pytrend.trending_searches(pn='brazil') # trending searches in real time for United States
df
# Out:
#                               0
# 0   Everton x Manchester United
# 1         Southampton x Chelsea
# 2            Atletico de Madrid
# 3                     Tottenham
# 4                Inter de Milão
# 5           Fluminense x Santos
# 6                      Juventus
# 7                      TV Globo
# 8                       Série A
# 9                         Betis
# 10          Brasileirão Série C
# 11                  Chapecoense
# 12               Dwayne Haskins
# 13           Randolfe Rodrigues
# 14                     Ypiranga
# 15                        Vasco
# 16             Bahia x Cruzeiro
# 17                         FGTS
# 18                  Brasileirao
# 19                    Formula 1

# %%
dir(pytrend)
# Out:
# ['CATEGORIES_URL',
#  'ERROR_CODES',
#  'GENERAL_URL',
#  'GET_METHOD',
#  'GetGoogleCookie',
#  'GetNewProxy',
#  'INTEREST_BY_REGION_URL',
#  'INTEREST_OVER_TIME_URL',
#  'POST_METHOD',
#  'REALTIME_TRENDING_SEARCHES_URL',
#  'RELATED_QUERIES_URL',
#  'SUGGESTIONS_URL',
#  'TODAY_SEARCHES_URL',
#  'TOP_CHARTS_URL',
#  'TRENDING_SEARCHES_URL',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_data',
#  '_tokens',
#  'backoff_factor',
#  'build_payload',
#  'categories',
#  'cookies',
#  'geo',
#  'get_historical_interest',
#  'google_rl',
#  'hl',
#  'interest_by_region',
#  'interest_by_region_widget',
# ...

# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# connect to google
pytrends = TrendReq(hl='pt-BR', tz=360)
# keywords to search for
pytrends.build_payload(kw_list=['Univer Vídeo', 'univer video'])

# dataframe
time_df = pytrends.interest_over_time()

# creating graph
fig, ax = plt.subplots(figsize=(13, 6))
time_df['soma']=time_df['Univer Vídeo']+time_df['univer video']
time_df['Univer Vídeo'].plot(color='red')
time_df['univer video'].plot(color='black')
time_df['soma'].plot(color='blue')
# adding title and labels
plt.title('Total Google Searches for "Univer Vídeo"', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
time_df
# Out:
#             Univer Vídeo  univer video  isPartial  soma
# date
# 2017-04-09             2            21      False    23
# 2017-04-16             4            24      False    28
# 2017-04-23             2            22      False    24
# 2017-04-30             0             9      False     9
# 2017-05-07             0            16      False    16
# ...                  ...           ...        ...   ...
# 2022-03-06             5            38      False    43
# 2022-03-13            11            18      False    29
# 2022-03-20             2            24      False    26
# 2022-03-27             7            19      False    26
# 2022-04-03             8            20       True    28
#
# [261 rows x 4 columns]

# %%
kw_list = ['Marilia Mendonça']
#pytrend.build_payload(kw_list, cat=0, timeframe='', geo='brazil', gprop='')

pytrend.get_historical_interest(kw_list, year_start=2021 month_start=1, day_start=1, hour_start=0, year_end=2021, month_end=2, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)
# Out:
#   File "C:\Users\Usuario\AppData\Local\Temp/ipykernel_6396/3107441477.py", line 4
#     pytrend.get_historical_interest(kw_list, year_start=2021 month_start=1, day_start=1, hour_start=0, year_end=2021, month_end=2, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)
#                                                              ^
# SyntaxError: invalid syntax

# %%
pytrends = TrendReq(hl='pt-BR', tz=360)

# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# connect to google
pytrends = TrendReq(hl='pt-BR', tz=360)
# keywords to search for
pytrends.build_payload(kw_list=['Bebi Liguei Marilia Mendonça', 'Passa Mal Ao Vivo'])

# dataframe
time_df = pytrends.interest_over_time()

# creating graph
fig, ax = plt.subplots(figsize=(13, 6))
time_df['soma']=time_df['Bebi Liguei Marilia Mendonça']+time_df['Passa Mal Ao Vivo']
time_df['Bebi Liguei Marilia Mendonça'].plot(color='red')
time_df['Passa Mal Ao Vivo'].plot(color='black')
time_df['soma'].plot(color='blue')
# adding title and labels
plt.title('Total Google Searches for "Univer Vídeo"', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')
